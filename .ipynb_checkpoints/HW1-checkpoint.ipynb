# %% [markdown]
# # Homework 1
#
# Student: Grigoryev Mikhail
#
# Group: J4133c

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy
import math

from scipy.sparse import diags
from scipy.optimize import root

from tqdm.notebook import tqdm

plt.rcParams["figure.facecolor"] = "white"
plt.rcParams["figure.figsize"] = (10, 6)

# %% [markdown]
# ## Importing data

# %%
data = pd.read_excel("age_data_2005.xlsx", sheet_name="both; 1950-2005, estimates")
data = data[data["Region"]=="Russian Federation"].replace("-", np.nan).reset_index(drop=True)
GROUPS = [f"{k*5} - {(k+1)*5-1}" for k in range(20)] + ["100+"]
SR = [f"SR: {k*5} - {(k+1)*5-1}" for k in range(1, 20)] + ["100+"]
YEARS = np.sort(data["Year"].unique())
data.loc[data["Year"].isin(
    YEARS[1:]
), SR] = data[data["Year"].isin(
    YEARS[1:]
)][GROUPS[1:]].values / data[data["Year"].isin(
    YEARS[:-1]
)][GROUPS[:-1]].values
data.head()
# Out:
#    Index    Variant              Region  Notes  Country code  Year      0 - 4  \
# 0    134  Estimates  Russian Federation    NaN           643  1950  10040.654
# 1    134  Estimates  Russian Federation    NaN           643  1955  12636.752
# 2    134  Estimates  Russian Federation    NaN           643  1960  13462.433
# 3    134  Estimates  Russian Federation    NaN           643  1965  12124.980
# 4    134  Estimates  Russian Federation    NaN           643  1970   9362.591
#
#        5 - 9    10 - 14    15 - 19  ...  SR: 50 - 54  SR: 55 - 59  \
# 0   7404.651  12243.902   9911.185  ...          NaN          NaN
# 1  10005.433   7398.446  12220.918  ...     0.956639     0.938264
# 2  12522.356   9937.392   7332.964  ...     0.950959     0.934875
# 3  13344.161  12434.071   9856.447  ...     0.954277     0.936820
# 4  12021.941  13253.940  12338.287  ...     0.953726     0.938938
#
#    SR: 60 - 64  SR: 65 - 69  SR: 70 - 74  SR: 75 - 79  SR: 80 - 84  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1     0.909740     0.873400     0.818419     0.737691     0.909280
# 2     0.907735     0.870054     0.815300     0.735130     0.909090
# 3     0.913481     0.877815     0.821757     0.741907     0.923018
# 4     0.913612     0.882182     0.827820     0.744879     0.932239
#
#    SR: 85 - 89  SR: 90 - 94  SR: 95 - 99
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 46 columns]

# %%
# TODO: merge GROUPS, merge SR, modify plotters

data_all = data.copy().drop(columns=data.iloc[:,:5])
data_all["Population"] = data_all[GROUPS].sum(axis=1)
data_all["SR"] = data_all[SR].mean(axis=1)
data_all = data_all[["Year", "Population", "SR"]].fillna(0.0)
data_all.head()
# Out:
#    Year  Population        SR
# 0  1950  102702.461  0.000000
# 1  1955  111401.500  0.940650
# 2  1960  119905.701  0.936148
# 3  1965  126749.102  0.939199
# 4  1970  130391.804  0.940886

# %%
dataM = pd.read_excel("age_data_2005.xlsx", sheet_name="m; 1950-2005, estimates")
dataM = dataM[dataM["Region"]=="Russian Federation"].replace("-", np.nan).reset_index(
    drop=True
)
dataM.loc[dataM["Year"].isin(
    YEARS[1:]
),SR] = dataM[dataM["Year"].isin(
    YEARS[1:]
)][GROUPS[1:]].values / dataM[dataM["Year"].isin(
    YEARS[:-1]
)][GROUPS[:-1]].values

# %%
dataM_all = dataM.copy().drop(columns=data.iloc[:,:5])
dataM_all["Population"] = dataM_all[GROUPS].sum(axis=1)
dataM_all["SR"] = dataM_all[SR].mean(axis=1)
dataM_all = dataM_all[["Year", "Population", "SR"]].fillna(0.0)
dataM_all.head()
# Out:
#    Year  Population        SR
# 0  1950   44078.085  0.000000
# 1  1955   48825.934  0.911718
# 2  1960   53471.925  0.907475
# 3  1965   57260.860  0.909716
# 4  1970   59367.866  0.909479

# %%
dataF = pd.read_excel("age_data_2005.xlsx", sheet_name="f; 1950-2005, estimates")
dataF = dataF[dataF["Region"]=="Russian Federation"].replace("-", np.nan).reset_index(
    drop=True
)
dataF.loc[dataF["Year"].isin(
    YEARS[1:]
),SR] = dataF[dataF["Year"].isin(
    YEARS[1:]
)][GROUPS[1:]].values / dataF[dataF["Year"].isin(
    YEARS[:-1]
)][GROUPS[:-1]].values

# %%
dataF_all = dataF.copy().drop(columns=data.iloc[:,:5])
dataF_all["Population"] = dataF_all[GROUPS].sum(axis=1)
dataF_all["SR"] = dataF_all[SR].mean(axis=1)
dataF_all = dataF_all[["Year", "Population", "SR"]].fillna(0.0)
dataF_all.head()
# Out:
#    Year  Population        SR
# 0  1950   58624.376  0.000000
# 1  1955   62575.566  0.954197
# 2  1960   66433.776  0.949807
# 3  1965   69488.242  0.953345
# 4  1970   71023.938  0.956183

# %% [markdown]
# ## Plotting functions

# %%
def plotter(datasets, years, features,
            remove=None, prefixes=None, title=None,
            styles=["-"], ylabel="Population"):
    colors = plt.get_cmap("viridis")(np.linspace(0, 1, len(years)))
    for k, data in enumerate(datasets):
        for it, year in enumerate(years):
            subdata = data[data["Year"]==year][features].dropna(axis=1)
            X = subdata.columns
            if remove is not None:
                X = [k.replace(remove, "") for k in X]
            Y = subdata.values.reshape(-1)
            if prefixes is not None:
                lbl = f"{year}-{prefixes[k]}"
            else:
                lbl = f"{year}"
            plt.plot(X, Y, label=lbl, linestyle=styles[k], color=colors[it])
            plt.scatter(X, Y, color=colors[it])
    plt.xticks(rotation=45)
    plt.xlabel("Age group")
    plt.ylabel(ylabel)
    plt.grid()
    plt.legend()
    if title is not None:
        plt.title(title)
    plt.show()

# %% [markdown]
# ## Initial analysis

# %%
plotter([data], features=GROUPS, years=data["Year"].unique()[-5:], title="All")

# %%
plt.plot(data_all.set_index("Year")["Population"]);
plt.grid()
plt.title("BOTH")
plt.xlabel("Year")
plt.ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %%
plotter([dataM], features=GROUPS, years=dataM["Year"].unique()[-5:], title="♂ Males ♂")

# %%
plotter([dataF], features=GROUPS, years=dataF["Year"].unique()[-5:], title="Females")

# %%
plotter([data], features=SR, years=data["Year"].unique(),
       remove="SR: ", title="All", ylabel="Survival rate")
# Out:
# /tmp/ipykernel_91669/891739200.py:16: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.plot(X, Y, label=lbl, linestyle=styles[k], color=colors[it])

# %%
plotter([dataM], features=SR, years=data["Year"].unique(),
       remove="SR: ", title="♂ Males ♂", ylabel="Survival rate")
# Out:
# /tmp/ipykernel_91669/891739200.py:16: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.plot(X, Y, label=lbl, linestyle=styles[k], color=colors[it])

# %%
plotter([dataF], features=SR, years=data["Year"].unique(),
       remove="SR: ", title="Females", ylabel="Survival rate")
# Out:
# /tmp/ipykernel_91669/891739200.py:16: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.plot(X, Y, label=lbl, linestyle=styles[k], color=colors[it])

# %% [markdown]
# ## Modelling

# %%
def Model(dataF, dataM, n1=4, n2=8, k_max=9, gamma1=1, gamma2=1):
    sr_m = dataM[dataM["Year"]==2005][SR].mean(axis=0).values
    sr_f = dataF[dataF["Year"]==2005][SR].mean(axis=0).values
    
    df_prof_m = [dataM[dataM["Year"]==2005][GROUPS].values.reshape(-1)]
    df_prof_f = [dataF[dataF["Year"]==2005][GROUPS].values.reshape(-1)]
    
    fert_rate = dataF[-3:]["FR"].mean()
    mf_ratio = (
        dataM[dataM["Year"]==2005][GROUPS[0]] \
                / (dataF[dataF["Year"]==2005][GROUPS[0]] + dataM[dataM["Year"]==2005][GROUPS[0]])
    ).values[0]
    
    years = [2005]
    
    for k in range(k_max):
        prof_m, prof_f = np.zeros(len(GROUPS)), np.zeros(len(GROUPS))
        prof_f[1:] = gamma2 * sr_f * df_prof_f[-1][:-1]
        prof_m[1:] = gamma2 * sr_m * df_prof_m[-1][:-1]
        prof_f[0] = gamma1**k * fert_rate * (prof_f[n1:n2]).sum() * (1-mf_ratio)
        prof_m[0] = gamma1**k * fert_rate * (prof_f[n1:n2]).sum() * mf_ratio
        # TODO: correct mf_ratio (0.49)
        
        df_prof_m.append(prof_m)
        df_prof_f.append(prof_f)
        years.append(years[-1] + 5)
    
    prof = [df_prof_m[k] + df_prof_f[k] for k in range(len(years))]
    pred = pd.DataFrame()
    pred["Year"] = years[1:]
    pred[GROUPS] = np.array(prof[1:])
    
    pred_m = pd.DataFrame()
    pred_m["Year"] = years[1:]
    pred_m[GROUPS] = np.array(df_prof_m[1:])
    
    pred_f = pd.DataFrame()
    pred_f["Year"] = years[1:]
    pred_f[GROUPS] = np.array(df_prof_f[1:])
    
    return pred, pred_m, pred_f

# %%
data_all.head()
# Out:
#    Year  Population        SR
# 0  1950  102702.461  0.000000
# 1  1955  111401.500  0.940650
# 2  1960  119905.701  0.936148
# 3  1965  126749.102  0.939199
# 4  1970  130391.804  0.940886

# %%
# def ModelAll(dataF, dataM, k_max=9):
#     sr_m = dataM[dataM["Year"]==2005]["SR"]
#     sr_f = dataF[dataF["Year"]==2005]["SR"]
    
#     df_prof_m = [dataM[dataM["Year"]==2005][GROUPS].values.reshape(-1)]
#     df_prof_f = [dataF[dataF["Year"]==2005][GROUPS].values.reshape(-1)]
    
#     fert_rate = dataF[-3:]["FR"].mean()
#     mf_ratio = (
#         dataM[dataM["Year"]==2005][GROUPS[0]] \
#                 / (dataF[dataF["Year"]==2005][GROUPS[0]] + dataM[dataM["Year"]==2005][GROUPS[0]])
#     ).values[0]
    
#     years = [2005]
    
#     for k in range(k_max):
#         prof_m, prof_f = np.zeros(len(GROUPS)), np.zeros(len(GROUPS))
#         prof_f[1:] = gamma2 * sr_f * df_prof_f[-1][:-1]
#         prof_m[1:] = gamma2 * sr_m * df_prof_m[-1][:-1]
#         prof_f[0] = gamma1**k * fert_rate * (prof_f[n1:n2]).sum()
#         prof_m[0] = gamma1**k * fert_rate * (prof_f[n1:n2]).sum() * mf_ratio
#         # TODO: correct mf_ratio (0.49)
        
#         df_prof_m.append(prof_m)
#         df_prof_f.append(prof_f)
#         years.append(years[-1] + 5)
    
#     prof = [df_prof_m[k] + df_prof_f[k] for k in range(len(years))]
#     pred = pd.DataFrame()
#     pred["Year"] = years[1:]
#     pred[GROUPS] = np.array(prof[1:])
    
#     pred_m = pd.DataFrame()
#     pred_m["Year"] = years[1:]
#     pred_m[GROUPS] = np.array(df_prof_m[1:])
    
#     pred_f = pd.DataFrame()
#     pred_f["Year"] = years[1:]
#     pred_f[GROUPS] = np.array(df_prof_f[1:])
    
#     return pred, pred_m, pred_f

# %%
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2

def Evaluate(data, data_pred):
    MAE = mae(
        data[GROUPS].values.T,
        data_pred[GROUPS].values.T,
        multioutput="raw_values"
    )
    RMSE = mse(
        data[GROUPS].values.T,
        data_pred[GROUPS].values.T,
        squared=False,
        multioutput="raw_values"
    )
    R2 = r2(
        data[GROUPS].values.T,
        data_pred[GROUPS].values.T,
        multioutput="raw_values"
    )
    
    df = pd.DataFrame()
    df["Year"] = data["Year"]
    df["Orig_Est"] = data[GROUPS].sum(axis=1).apply(int)
    df["Pred"] = data_pred[GROUPS].sum(axis=1).apply(int)
    df["MAE"] = np.round(MAE, 0).astype("int")
    df["RMSE"] = np.round(RMSE, 0).astype("int")
    df["R2"] = np.round(R2, 3)
    return df

# def EvaluateAll(data, data_pred):
#     MAE = mae(
#         np.array(data["Population"]),#.reshape((-1, 1)),
#         np.array(data_pred["Population"]),#.reshape((-1, 1)),
#         multioutput="raw_values"
#     )
#     RMSE = mse(
#         np.array(data["Population"]),#.reshape((-1, 1)),
#         np.array(data_pred["Population"]),#.reshape((-1, 1)),
#         squared=False,
#         multioutput="raw_values"
#     )
#     R2 = r2(
#         np.array(data["Population"]),#.reshape((-1, 1)),
#         np.array(data_pred["Population"]),#.reshape((-1, 1)),
#         multioutput="raw_values"
#     )
    
#     print(np.array(data["Population"]),#.reshape((-1, 1)))
    
#     df = pd.DataFrame()
#     df["Year"] = data["Year"]
#     df["Orig_Est"] = data["Population"].apply(int)
#     df["Pred"] = data_pred["Population"].apply(int)
#     df["MAE"] = np.round(MAE, 0).astype("int")
#     df["RMSE"] = np.round(RMSE, 0).astype("int")
#     df["R2"] = np.round(R2, 3)
#     return df

# %%
n1 = 4
n2 = 8

# dataM["FR"] = dataM[GROUPS[0]] / dataM[GROUPS[n1:n2]].sum(axis=1)
dataF["FR"] = dataF[GROUPS[0]] / dataF[GROUPS[n1:n2]].sum(axis=1)
data_pred, data_pred_M, data_pred_F = Model(dataF, dataM, n1=n1, n2=n2)

# dataM["FR"] = dataM[GROUPS[0]] / dataM[GROUPS[n1:n2]].sum(axis=1)
# dataF["FR"] = dataF[GROUPS[0]] / dataF[GROUPS[n1:n2]].sum(axis=1)
# data_pred, data_pred_M, data_pred_F = Model(dataF, dataM, n1=n1, n2=n2)

# %% [markdown]
# ## Comparison

# %% [markdown]
# ### Both

# %%
# data2_all = pd.read_excel("age_data_2005.xlsx", sheet_name="both; 2010-50, medium-fertility")
# data2_all = data2_all[data2_all["Region"]=="Russian Federation"].replace(
#     "-",
#     np.nan
# ).reset_index(drop=True)
# data2_all.drop(columns=data2_all.iloc[:,:5], inplace=True)
# # data2_all.head()
# plt.plot(data2_all.set_index("Year"));
# plt.grid()

# %%
# data2_all["Population"] = data2_all.iloc[:,1:].sum(axis=1)
# data2_all = data2_all[["Year", "Population"]]
# data2_all.head()

# %%
# plt.plot(data2_all.set_index("Year"))
# plt.grid()

# %%
data2 = pd.read_excel("age_data_2005.xlsx", sheet_name="both; 2010-50, medium-fertility")
data2 = data2[data2["Region"]=="Russian Federation"].replace(
    "-",
    np.nan
).reset_index(drop=True)
YEARS2 = np.sort(data2["Year"].unique())
data2.loc[data2["Year"].isin(
    YEARS2[1:]
), SR] = data2[data2["Year"].isin(
    YEARS2[1:]
)][GROUPS[1:]].values / data2[data2["Year"].isin(
    YEARS2[:-1]
)][GROUPS[:-1]].values
data2["FR"] = data2[GROUPS[0]] / data2[GROUPS[n1:n2]].sum(axis=1)

# %%
plotter(
    [data2],
    features=GROUPS,
    years=data2["Year"].unique(),
    title="Original Estimation: Both"
)

# %%
plotter(
    [data_pred],
    features=GROUPS,
    years=data_pred['Year'].unique(),
    title="Prediction: Both"
)

# %%
plt.plot(data2.set_index("Year")[GROUPS].sum(axis=1));
plt.grid()
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Original estimation: both")
# Out:
# Text(0.5, 1.0, 'Original estimation: both')

# %%
data2_all = data2.copy()
data2_all["Population"] = data2_all.iloc[:,1:].sum(axis=1)
data2_all = data2_all[["Year", "Population"]]

data_pred_all = data_pred.copy()
data_pred_all["Population"] = data_pred_all.iloc[:,1:].sum(axis=1)
data_pred_all = data_pred_all[["Year", "Population"]]

data2_all.head()
# Out:
# /tmp/ipykernel_91669/3288363563.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data2_all["Population"] = data2_all.iloc[:,1:].sum(axis=1)
#    Year     Population
# 0  2010  142681.390588
# 1  2015  139356.133993
# 2  2020  135768.982371
# 3  2025  131898.544550
# 4  2030  127989.314970

# %%
Evaluate(data2, data_pred)
# Out:
#    Year  Orig_Est    Pred   MAE  RMSE     R2
# 0  2010    140028  136005   225   893  0.950
# 1  2015    136682  128445   459  1250  0.892
# 2  2020    133089  120470   680  1495  0.828
# 3  2025    129214  112079   885  1683  0.753
# 4  2030    125299  103013  1102  1896  0.642
# 5  2035    121653   93590  1341  2143  0.475
# 6  2040    118299   84012  1634  2411  0.242
# 7  2045    115071   74390  1938  2680 -0.055
# 8  2050    111711   65119  2220  2906 -0.392

# %%
#EvaluateAll(data2_all, data_pred_all)

# %%
plotter(
    [data2, data_pred],
    features=GROUPS,
    years=data_pred["Year"].unique()[:3],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Both"
)

# %%
plotter(
    [data2, data_pred],
    features=GROUPS,
    years=data_pred["Year"].unique()[3:6],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Both"
)

# %%
plotter(
    [data2, data_pred],
    features=GROUPS,
    years=data_pred["Year"].unique()[6:9],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Both"
)

# %%
data_print_both = data2.copy().drop(columns=data2.iloc[:,:5])
data_print_both["Total"] = data_print_both[GROUPS].sum(axis=1)
data_print_both = data_print_both[["Year", "Total"]]
# data_print_both.head()

data_print_pred_both = data_pred.copy()
data_print_pred_both["Total"] = data_print_pred_both[GROUPS].sum(axis=1)
data_print_pred_both = data_print_pred_both[["Year", "Total"]]
data_print_pred_both.head()
# Out:
#    Year          Total
# 0  2010  136005.787699
# 1  2015  128445.504817
# 2  2020  120470.125138
# 3  2025  112079.389688
# 4  2030  103013.800678

# %%
plt.plot(data_print_both.set_index("Year"), label="Original")
plt.plot(data_print_pred_both.set_index("Year"), label="Prediction")
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Population: both")
plt.grid()
plt.legend()

# %% [markdown]
# ### Males

# %%
data2 = pd.read_excel("age_data_2005.xlsx", sheet_name="m; 2010-50, medium-fertility")
data2 = data2[data2["Region"]=="Russian Federation"].replace(
    "-",
    np.nan
).reset_index(drop=True)

YEARS2 = np.sort(data2["Year"].unique())
data2.loc[data2["Year"].isin(
    YEARS2[1:]
), SR] = data2[data2["Year"].isin(
    YEARS2[1:]
)][GROUPS[1:]].values / data2[data2["Year"].isin(
    YEARS2[:-1]
)][GROUPS[:-1]].values

data2['FR'] = data2[GROUPS[0]] / data2[GROUPS[n1:n2]].sum(axis=1)

# %%
data2_all = data2.copy()
data2_all["Population"] = data2_all.iloc[:,1:].sum(axis=1)
data2_all = data2_all[["Year", "Population"]]

data_pred_all = data_pred_M.copy()
data_pred_all["Population"] = data_pred_all.iloc[:,1:].sum(axis=1)
data_pred_all = data_pred_all[["Year", "Population"]]

data2_all.head()
# Out:
# /tmp/ipykernel_91567/302256925.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data2_all["Population"] = data2_all.iloc[:,1:].sum(axis=1)
#    Year    Population
# 0  2010  67312.768573
# 1  2015  65537.462473
# 2  2020  63709.302083
# 3  2025  61809.558257
# 4  2030  59969.537427

# %%
plotter(
    [data2],
    features=GROUPS,
    years=data2["Year"].unique(),
    title="Original Estimation: Males"
)

# %%
plotter(
    [data_pred_M],
    features=GROUPS,
    years=data_pred_M["Year"].unique(),
    title="Prediction: Males"
)

# %%
Evaluate(data2, data_pred_M)
# Out:
#    Year  Orig_Est   Pred   MAE  RMSE     R2
# 0  2010     64659  62632   114   459  0.950
# 1  2015     62864  58639   230   641  0.890
# 2  2020     61030  54440   340   766  0.823
# 3  2025     59125  50045   443   863  0.745
# 4  2030     57280  45367   568   973  0.632
# 5  2035     55674  40629   717  1103  0.470
# 6  2040     54332  35955   876  1247  0.250
# 7  2045     53130  31368  1036  1394 -0.032
# 8  2050     51897  27029  1185  1519 -0.358

# %%
plotter(
    [data2, data_pred_M],
    features=GROUPS,
    years=data_pred_M["Year"].unique()[:3],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Males"
)

# %%
plotter(
    [data2, data_pred_M],
    features=GROUPS,
    years=data_pred_M["Year"].unique()[3:6],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Males"
)

# %%
plotter(
    [data2, data_pred_M],
    features=GROUPS,
    years=data_pred_M["Year"].unique()[6:9],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Males"
)

# %%
data_print_M = data2.copy().drop(columns=data2.iloc[:,:5])
data_print_M["Total"] = data_print_M[GROUPS].sum(axis=1)
data_print_M = data_print_M[["Year", "Total"]]
# data_print_both.head()

data_print_pred_M = data_pred_M.copy()
data_print_pred_M["Total"] = data_print_pred_M[GROUPS].sum(axis=1)
data_print_pred_M = data_print_pred_M[["Year", "Total"]]
data_print_pred_M.head()

# %%
plt.plot(data_print_M.set_index("Year"), label="Original")
plt.plot(data_print_pred_M.set_index("Year"), label="Prediction")
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Population: males")
plt.legend();
plt.grid()

# %% [markdown]
# ### Females

# %%
data2 = pd.read_excel("age_data_2005.xlsx", sheet_name="f; 2010-50, medium-fertility")
data2 = data2[data2["Region"]=="Russian Federation"].replace(
    "-",
    np.nan
).reset_index(drop=True)
YEARS2 = np.sort(data2["Year"].unique())
data2.loc[data2["Year"].isin(
    YEARS2[1:]
), SR] = data2[data2["Year"].isin(
    YEARS2[1:]
)][GROUPS[1:]].values / data2[data2["Year"].isin(
    YEARS2[:-1]
)][GROUPS[:-1]].values
data2["FR"] = data2[GROUPS[0]] / data2[GROUPS[n1:n2]].sum(axis=1)

# %%
data2_all = data2.copy()
data2_all["Population"] = data2_all.iloc[:,1:].sum(axis=1)
data2_all = data2_all[["Year", "Population"]]

data_pred_all = data_pred_F.copy()
data_pred_all["Population"] = data_pred_all.iloc[:,1:].sum(axis=1)
data_pred_all = data_pred_all[["Year", "Population"]]

data2_all.head()
# Out:
# /tmp/ipykernel_91669/1562060639.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data2_all["Population"] = data2_all.iloc[:,1:].sum(axis=1)
#    Year     Population
# 0  2010  142681.390588
# 1  2015  139356.133993
# 2  2020  135768.982371
# 3  2025  131898.544550
# 4  2030  127989.314970

# %%
plotter(
    [data2],
    features=GROUPS,
    years=data2["Year"].unique(),
    title="Original Estimation: Females"
)

# %%
plotter(
    [data_pred_F],
    features=GROUPS,
    years=data_pred_F["Year"].unique(),
    title="Prediction: Females"
)

# %%
Evaluate(data2, data_pred_F)
# Out:
#    Year  Orig_Est   Pred   MAE  RMSE     R2
# 0  2010     75368  73373   111   435  0.952
# 1  2015     73818  69805   229   609  0.899
# 2  2020     72059  66029   343   730  0.843
# 3  2025     70088  62033   450   823  0.779
# 4  2030     68019  57645   565   929  0.682
# 5  2035     65979  52960   689  1050  0.528
# 6  2040     63966  48056   814  1179  0.306
# 7  2045     61941  43022   938  1304  0.021
# 8  2050     59813  38089  1051  1405 -0.287

# %%
plotter(
    [data2, data_pred_F],
    features=GROUPS,
    years=data_pred_F["Year"].unique()[:3],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Females"
)

# %%
plotter(
    [data2, data_pred_F],
    features=GROUPS,
    years=data_pred_F["Year"].unique()[3:6],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Females"
)

# %%
plotter(
    [data2, data_pred_F],
    features=GROUPS,
    years=data_pred_F["Year"].unique()[6:9],
    prefixes=["Orig", "Pred"],
    styles=["-", "--"],
    title="Females"
)

# %%
data_print_F = data2.copy().drop(columns=data2.iloc[:,:5])
data_print_F["Total"] = data_print_F[GROUPS].sum(axis=1)
data_print_F = data_print_F[["Year", "Total"]]
# data_print_both.head()

data_print_pred_F = data_pred_F.copy()
data_print_pred_F["Total"] = data_print_pred_F[GROUPS].sum(axis=1)
data_print_pred_F = data_print_pred_F[["Year", "Total"]]
data_print_pred_F.head()

# %%
plt.plot(data_print_F.set_index("Year"), label="Original")
plt.plot(data_print_pred_F.set_index("Year"), label="Prediction")
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Population: females")
plt.legend();
plt.grid()

# %% [markdown]
# TODO: plot whole population
